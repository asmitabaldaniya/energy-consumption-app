# %% [markdown]
# <a href="https://colab.research.google.com/github/asmitabaldaniya/energy-consumption-app/blob/main/cell2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Import libraries
import pandas as pd
import numpy as np

# STEP 2: Create fake energy data
n = 500
df = pd.DataFrame({
    'Batch_Size': np.random.randint(100, 500, n),
    'Temperature': np.random.normal(30, 5, n),
    'Load': np.random.uniform(0.5, 1.5, n),
    'Energy_Consumed': np.random.normal(100, 10, n)
})
df.head()
# Out:
#    Batch_Size  Temperature      Load  Energy_Consumed
# 0         153    29.374198  1.130885       106.481960
# 1         364    26.842540  0.908953        94.118483
# 2         408    33.956958  1.394323        78.860793
# 3         428    30.127036  0.675864       106.700325
# 4         447    27.826345  0.707119        88.328892

# %%
# STEP 2: Train-Test Split
from sklearn.model_selection import train_test_split

X = df[['Batch_Size', 'Temperature', 'Load']]
y = df['Energy_Consumed']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# STEP 3: Train Random Forest Model
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

# STEP 4: Predict
y_pred = model.predict(X_test)

# STEP 5: Evaluate Model
from sklearn.metrics import mean_squared_error, r2_score

print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# RMSE: 10.669732699237356
# R² Score: -0.2090228640934828

# %%
# Recreate energy with relation to input features
df['Energy_Consumed'] = (
    0.2 * df['Batch_Size'] +
    1.5 * df['Temperature'] +
    10 * df['Load'] +
    np.random.normal(0, 5, len(df))  # small noise
)

# Re-run model steps again (training + evaluation)
X = df[['Batch_Size', 'Temperature', 'Load']]
y = df['Energy_Consumed']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("✅ RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("✅ R² Score:", r2_score(y_test, y_pred))
# Out:
# ✅ RMSE: 5.824719193820858
# ✅ R² Score: 0.9453084207613449

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test.values[:50], label='Actual', marker='o')
plt.plot(y_pred[:50], label='Predicted', marker='x')
plt.title("Actual vs Predicted Energy Consumption")
plt.xlabel("Sample")
plt.ylabel("Energy (kWh)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# app.py
with open("app.py", "w") as f:
    f.write("""<-- Paste here the app.py code I gave -->""")

# requirements.txt
with open("requirements.txt", "w") as f:
    f.write("gradio\nscikit-learn\nnumpy")

# %%
# !git config --global user.email "asmitabaldaniya85@gmail.com"
# !git config --global user.name "asmita"

# %%
# !git init
# !git remote add origin https://github.com/asmitabaldaniya85/energy-consumption-app.git
# !git branch -M main
# !git add app.py requirements.txt
# !git commit -m "added app and requirements"
# !git push https://<asmitabaldaniya85>:<your-github-token>@github.com/<asmitabaldaniya85>/energy-consumption-app.git main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# [main (root-commit) 35111fd] added app and requirements
#  2 files changed, 4 insertions(+)
#  create mode 100644 app.py
#  create mode 100644 requirements.txt
# /bin/bash: line 1: asmitabaldaniya85: No such file or directory
